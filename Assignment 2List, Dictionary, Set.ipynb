# %% [markdown]
# # **List**

# %%
age_list=[24, 25, 26, 27, 28]
print(age_list)
# Out:
# [24, 25, 26, 27, 28]

# %%
name_list=['Arun','Bala','Ramesh','Deepa','Karthik']
print(name_list)
# Out:
# ['Arun', 'Bala', 'Ramesh', 'Deepa', 'Karthik']

# %% [markdown]
# # **List Operations**

# %%
name_list.append("Yazhini")

# %%
print(name_list)
# Out:
# ['Arun', 'Bala', 'Ramesh', 'Deepa', 'Karthik', 'Yazhini']

# %%
age_list.insert(2,30)

# %%
print(age_list)
# Out:
# [24, 25, 30, 26, 27, 28]

# %%
name_list.remove("Yazhini")

# %%
print(name_list)
# Out:
# ['Arun', 'Bala', 'Ramesh', 'Deepa', 'Karthik']

# %%
age_list.pop()
# Out:
# 28

# %%
print(age_list)
# Out:
# [24, 25, 30, 26, 27]

# %%
age_list.extend([29,30,26])

# %%
print(age_list)
# Out:
# [24, 25, 30, 26, 27, 29, 30, 26]

# %%
age_list.sort(reverse=True)

# %%
print(age_list)
# Out:
# [30, 30, 29, 27, 26, 26, 25, 24]

# %%
min(age_list)
# Out:
# 24

# %%
max(age_list)
# Out:
# 30

# %%
sum(age_list)
# Out:
# 217

# %% [markdown]
# # **Accessing List Elements**

# %%
name_list[1]
# Out:
# 'Bala'

# %%
name_list[-1]
# Out:
# 'Karthik'

# %%
name_list[2:4]
# Out:
# ['Ramesh', 'Deepa']

# %%
name_list.reverse()

# %%
print(name_list)
# Out:
# ['Karthik', 'Deepa', 'Ramesh', 'Bala', 'Arun']

# %% [markdown]
# ## **Dictionary**

# %%
student_marks = {
    "Arun": 85,
    "Bala": 78,
    "Kumar": 92,
    "Divya": 88,
    "Yazhini": 95
}
print(student_marks)
# Out:
# {'Arun': 85, 'Bala': 78, 'Kumar': 92, 'Divya': 88, 'Yazhini': 95}

# %%
print(student_marks)
# Out:
# {'Arun': 85, 'Bala': 78, 'Kumar': 92, 'Divya': 88, 'Yazhini': 95}

# %%
print(student_marks)
# Out:
# {'Arun': 85, 'Bala': 78, 'Kumar': 92, 'Divya': 88, 'Yazhini': 95}

# %%
print(student_marks['Bala'])
# Out:
# 78

# %%
student_marks["Janani"]=80

# %%
print(student_marks)
# Out:
# {'Arun': 85, 'Bala': 78, 'Kumar': 92, 'Divya': 88, 'Yazhini': 95, 'Janani': 80}

# %%
student_marks['Divya']=82

# %%
print(student_marks)
# Out:
# {'Arun': 85, 'Bala': 78, 'Kumar': 92, 'Divya': 82, 'Yazhini': 95, 'Janani': 80}

# %%
student_marks.keys()
# Out:
# dict_keys(['Arun', 'Bala', 'Kumar', 'Divya', 'Yazhini', 'Janani'])

# %%
student_marks.values()
# Out:
# dict_values([85, 78, 92, 82, 95, 80])

# %%
student_marks.items()
# Out:
# dict_items([('Arun', 85), ('Bala', 78), ('Kumar', 92), ('Divya', 82), ('Yazhini', 95), ('Janani', 80)])

# %% [markdown]
# # **Sets**

# %%
my_set={'a','e','i','o','u','a','a','i'}

# %%
print(my_set)
# Out:
# {'e', 'o', 'i', 'u', 'a'}

# %%
my_set[4]='s'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_152/3822229113.py in <cell line: 0>()
# ----> 1 my_set[4]='s'
#
# TypeError: 'set' object does not support item assignment

# %%
'set' object does not support indexing

# %%
set1={1, 3, 5, 7, 9}
set2={2, 3, 5, 8, 10}
print(set1.union(set2))
# Out:
# {1, 2, 3, 5, 7, 8, 9, 10}

# %%
print(set1.intersection(set2))
# Out:
# {3, 5}

# %% [markdown]
# # **Operators** **& Conditional Statements**

# %%
score=int(input("enter your score :"))
if score > 7:
   print("Performance Category: Above Average")
   print('Excellent performance! Keep up the great work')
elif 4<=score<=7:
  print("Performance Category: Average")
  print('Good effort. With a little more practice, you can do even better')
else :
   print("Performance Category: Below Average")
   print("Need to improve your performance. Consistent practice will lead to better results.")
# Out:
# enter your score :5
# Performance Category: Average
# Good effort. With a little more practice, you can do even better
